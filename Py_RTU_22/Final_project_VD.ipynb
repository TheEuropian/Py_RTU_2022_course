# %%
print("Compare two small online shops(Shop1 and Shop2)")
print("We use one month (Dec) data for each shop from 2017 till 2021")

# Let's start with Shop1
# Out:
# Compare two small online shops(Shop1 and Shop2)
# We use one month (Dec) data for each shop from 2017 till 2021

# %%
import pandas as pd
df1 = pd.read_csv("..\Py_RTU_22\Shop1\Shop1_21.csv", sep = ";")
df1.head()
# Out:
#   Sale Date  Number of Items Ship State   Ship Country Currency  Order Value  \
# 0  12/29/21                1         FL  United States      USD         39.0
# 1  12/24/21                1        NSW      Australia      USD         55.0
# 2  12/24/21                1         SK         Canada      USD         46.0
# 3  12/23/21                1         FL  United States      USD         47.0
# 4  12/22/21                1         FL  United States      USD         47.0
#
#   Coupon Code Coupon Details  Shipping  Order Total  Order Net
# 0         NaN            NaN       7.0        48.76      37.59
# 1         NaN            NaN       7.0        68.20      50.74
# 2         NaN            NaN       7.0        53.00      43.51
# 3         NaN            NaN       7.0        57.51      44.28
# 4         NaN            NaN       7.0        57.78      44.21

# %%
total_shop1_21 = sum(list(df1["Order Total"]))
total_shop1_21 = round(total_shop1_21,2)
print(total_shop1_21)
# Out:
# 1453.73

# %%
df2 = pd.read_csv(r"..\Py_RTU_22\Shop1\Shop1_20.csv", sep = ";")
df2.head()
# Out:
#   Sale Date  Number of Items Ship State   Ship Country Currency  Order Value  \
# 0  12/31/20                1        NSW      Australia      USD        53.04
# 1  12/30/20                1         NC  United States      USD        51.00
# 2  12/29/20                1     ATTIKI         Greece      USD        43.03
# 3  12/25/20                2         IL  United States      USD        58.00
# 4  12/25/20                1         UT  United States      USD        39.00
#
#   Coupon Code Coupon Details  Shipping  Order Total Order Net
# 0         NaN            NaN       5.0        63.84     43.99
# 1         NaN            NaN       0.0        54.83     38.37
# 2   INTEPRO15          % off       5.0        41.58     31.49
# 3         NaN            NaN       0.0        63.95     44.03
# 4  10PERCENTS          % off       0.0        37.71     26.56

# %%
total_shop1_20 = sum(list(df2["Order Total"]))
total_shop1_20 = round(total_shop1_20,2)
print(total_shop1_20)
# Out:
# 2459.34

# %%
df3 = pd.read_csv(r"..\Py_RTU_22\Shop1\Shop1_19.csv", sep = ";")
df3.head()
# Out:
#   Sale Date  Number of Items Ship State   Ship Country Currency  Order Value  \
# 0  12/29/19                1         MT  United States      USD         35.0
# 1  12/28/19                1        NSW      Australia      USD         43.0
# 2  12/27/19                1         ME  United States      USD         35.0
# 3  12/22/19                1    iceland        Iceland      USD         57.0
# 4  12/20/19                1         FL  United States      USD         37.0
#
#   Coupon Code Coupon Details  Shipping  Order Total  Order Net
# 0         NaN            NaN       3.0        38.00      31.53
# 1         NaN            NaN       3.0        50.60      38.07
# 2     FORSALE          % off       3.0        32.54      25.59
# 3         NaN            NaN       3.0        60.00      50.40
# 4     FORSALE          % off       0.0        29.60      24.72

# %%
total_shop1_19 = sum(list(df3["Order Total"]))
total_shop1_19 = round(total_shop1_19,2)
print(total_shop1_19)
# Out:
# 2220.79

# %%
df4 = pd.read_csv(r"..\Py_RTU_22\Shop1\Shop1_18.csv", sep = ";")
df4.head()
# Out:
#   Sale Date  Number of Items Ship State   Ship Country Currency  Order Value  \
# 0  12/28/18                1         LA  United States      USD         37.0
# 1  12/28/18                1     MADRID          Spain      USD         57.0
# 2  12/27/18                1        NaN        Germany      USD         37.0
# 3  12/26/18                1         CA  United States      USD         37.0
# 4  12/25/18                1         NJ  United States      USD         37.0
#
#            Coupon Code Coupon Details  Shipping  Order Total Order Net
# 0  ONSALE30PERCENTSOFF          % off       0.0         25.9     25.90
# 1                  NaN            NaN       0.0         57.0     57.00
# 2     MAPSFLOWERS10OFF          % off       0.0         33.3     33.30
# 3                  NaN            NaN       0.0         37.0     37.00
# 4     MAPSFLOWERS10OFF          % off       0.0         33.3     27.01

# %%
total_shop1_18 = sum(list(df4["Order Total"]))
total_shop1_18 = round(total_shop1_18,2)
print(total_shop1_18)
# Out:
# 2932.22

# %%
df5 = pd.read_csv(r"..\Py_RTU_22\Shop1\Shop1_17.csv", sep = ";")
df5.head()
# Out:
#   Sale Date  Number of Items Ship State   Ship Country Currency  Order Value  \
# 0  12/30/17                1         NJ  United States      USD         39.0
# 1  12/30/17                1         CA  United States      USD         49.0
# 2  12/29/17                1         MD  United States      USD         59.0
# 3  12/27/17                1         WA  United States      USD         59.0
# 4  12/27/17                1         OR  United States      USD         39.0
#
#   Coupon Code Coupon Details Discount Amount  Shipping  Order Total Order Net
# 0      SALE15          % off        maijs.85       4.0        37.15     28.66
# 1      SALE15          % off          j?l.35       4.0        45.65     35.30
# 2      SALE15          % off          aug.85       0.0        50.15     38.81
# 3      SALE15          % off          aug.85       4.0        54.15     42.30
# 4      SALE15          % off        maijs.85       4.0        37.15     28.98

# %%
total_shop1_17 = sum(list(df5["Order Total"]))
total_shop1_17 = round(total_shop1_17)
print(total_shop1_17)
# Out:
# 6418

# %%
#apkopotie dati: Pirmā veikala apgrozījumi decembra mēnešos, no 2017 līdz 2021gadam.
#Mazā online exporta biznesa kritums pandēmijas un citu faktoru ietekmē.
shop1_dict={"Sh1_17":total_shop1_17,"Sh1_18":total_shop1_18,"Sh1_19":total_shop1_19,"Sh1_20":total_shop1_20,"Sh1_21":total_shop1_21}
print(shop1_dict)
# Out:
# {'Sh1_17': 6418, 'Sh1_18': 2932.22, 'Sh1_19': 2220.79, 'Sh1_20': 2459.34, 'Sh1_21': 1453.73}

# %%
import numpy as np 
import matplotlib.pyplot as plt
plt.bar(shop1_dict.keys(), shop1_dict.values())
plt.show()

# %%
dfs1 = pd.read_csv("..\Py_RTU_22\Shop2\Shop2_17", sep = ",")
dfs1.head()
# Out:
#   Sale Date  Number of Items Ship State   Ship Country Currency  Order Value  \
# 0  12/30/17                1         WI  United States      USD         18.0
# 1  12/30/17                1         OR  United States      USD         35.0
# 2  12/30/17                1         WI  United States      USD         46.0
# 3  12/30/17                1         GA  United States      USD         35.0
# 4  12/29/17                1         CA  United States      USD         33.0
#
#    Shipping  Order Total  Order Net
# 0      4.85        22.85      22.85
# 1      4.85        39.85      30.78
# 2      4.85        46.25      35.78
# 3      4.85        36.35      28.06
# 4      4.85        34.55      26.65

# %%
total_shop2_17 = sum(list(dfs1["Order Total"]))
total_shop2_17 = round(total_shop2_17)
print(total_shop2_17)
# Out:
# 10848

# %%
dfs2 = pd.read_csv("..\Py_RTU_22\Shop2\Shop2_18", sep = ",")
dfs2.head()
# Out:
#   Sale Date  Number of Items Ship State   Ship Country Currency  Order Value  \
# 0  12/31/18                1         NC  United States      USD         35.0
# 1  12/30/18                1         CA  United States      USD         46.0
# 2  12/29/18                1         NC  United States      USD         35.0
# 3  12/29/18                1        NaN         France      USD         35.0
# 4  12/29/18                1         VA  United States      USD         49.0
#
#    Shipping  Order Total  Order Net
# 0       0.0         31.5      31.50
# 1       0.0         46.0      37.34
# 2       0.0         35.0      35.00
# 3       0.0         35.0      28.34
# 4       0.0         49.0      49.00

# %%
total_shop2_18 = sum(list(dfs2["Order Total"]))
total_shop2_18 = round(total_shop2_18)
print(total_shop2_18)
# Out:
# 7814

# %%
dfs3 = pd.read_csv("..\Py_RTU_22\Shop2\Shop2_19", sep = ",")
dfs3.head()
# Out:
#   Sale Date  Number of Items Ship State   Ship Country Currency  Order Value  \
# 0  12/31/19                1         IL  United States      USD         46.0
# 1  12/31/19                1         OR  United States      USD         32.0
# 2  12/30/19                1         LA  United States      USD         35.0
# 3  12/28/19                1         MS  United States      USD         46.0
# 4  12/28/19                1         AL  United States      USD         35.0
#
#    Shipping  Order Total  Order Net
# 0       0.0         46.0      38.04
# 1       4.0         36.0      29.78
# 2       0.0         35.0      28.94
# 3       0.0         46.0      38.23
# 4       0.0         37.8      28.92

# %%
total_shop2_19 = sum(list(dfs3["Order Total"]))
total_shop2_19 = round(total_shop2_19)
print(total_shop2_19)
# Out:
# 4546

# %%
dfs4 = pd.read_csv("..\Py_RTU_22\Shop2\Shop2_20", sep = ",")
dfs4.head()
# Out:
#   Sale Date  Number of Items        Ship State    Ship Country Currency  \
# 0  12/31/20                1               NaN         Germany      USD
# 1  12/30/20                1                CA   United States      USD
# 2  12/30/20                1                CA   United States      USD
# 3  12/29/20                1               NSW       Australia      USD
# 4  12/29/20                1  Northamptonshire  United Kingdom      USD
#
#    Order Value  Shipping  Order Total  Order Net
# 0        37.00       5.0        42.00      31.74
# 1        63.00       0.0        61.09      42.75
# 2        52.00       0.0        56.03      39.19
# 3        37.02       5.0        46.22      31.56
# 4        50.02       5.0        55.02      41.68

# %%
total_shop2_20 = sum(list(dfs4["Order Total"]))
total_shop2_20 = round(total_shop2_20)
print(total_shop2_20)
# Out:
# 4664

# %%
dfs5 = pd.read_csv("..\Py_RTU_22\Shop2\Shop2_21", sep = ",")
dfs5.head()
# Out:
#   Sale Date  Number of Items Ship State   Ship Country Currency  Order Value  \
# 0  12/31/21                1         VA  United States      USD         18.0
# 1  12/28/21                1   Asturias          Spain      USD         35.0
# 2  12/27/21                1         TX  United States      USD         37.0
# 3  12/27/21                1         TX  United States      USD         48.0
# 4  12/25/21                1         OK  United States      USD         37.0
#
#    Shipping  Order Total  Order Net
# 0       5.0        23.95      18.58
# 1       5.0        40.00      32.81
# 2       0.0        40.05      30.18
# 3       0.0        51.96      39.23
# 4       0.0        40.30      30.17

# %%
total_shop2_21 = sum(list(dfs5["Order Total"]))
total_shop2_21 = round(total_shop2_21)
print(total_shop2_21)
# Out:
# 2390

# %%
shop2_dict={"Shop2_17":total_shop2_17,"Shop2_18":total_shop2_18,"Shop2_19":total_shop2_19,"Shop2_20":total_shop2_20,"Shop2_21":total_shop2_21}
print(shop2_dict)
# Out:
# {'Shop2_17': 10848, 'Shop2_18': 7814, 'Shop2_19': 4546, 'Shop2_20': 4664, 'Shop2_21': 2390}

# %%
plt.bar(shop2_dict.keys(), shop2_dict.values())
plt.show()

# %%
years=[2017,2018,2019,2020,2021]

# %%
print(shop2_dict.values())
# Out:
# dict_values([10848, 7814, 4546, 4664, 2390])

# %%
  
n=5
r = np.arange(n)
width = 0.25
  
  
plt.bar(r,shop1_dict.values() , color = 'b',
        width = width, edgecolor = 'black',
        label='MENS Shop 1')
plt.bar(r + width, shop2_dict.values(), color = 'r',
        width = width, edgecolor = 'black',
        label='LADIES Shop 2')
  

plt.ylabel("Turnover in December (Euros)")
plt.title("Man's shop vs Ladies shop")
  
# plt.grid(linestyle='--')
plt.xticks(r + width/2,years)
plt.legend()
  
plt.show()
